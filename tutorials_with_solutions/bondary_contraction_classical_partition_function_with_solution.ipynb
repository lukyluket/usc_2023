# %% [markdown]
# # Fixed point of the boundary contraction
#
# We contract the partition function in terms of boundary MPS, the full upper plane will at the end be encoded in the norm of an infinite matrix product state
# ![](../pictures/mps_norm.png) (should be infinite not finte)
#
# The infinite MPS is the fixed point of an infinite operator in a matrix product operator form (MPO).
# ![](../pictures/mpo.png)
#
# The infinite MPO is constructed from elementary tensors
# $$T$$, each made by elementary Boltzamn weight $M$ the first step is thus to construct the Boltzmann weight.
#
# ## Local Boltzmann weight
#
# We start by defining the local Boltzmann weight
# $$M(i,j) = \exp(-\beta(-\sigma_i \sigma_j - 0.5 h(\sigma_i +\sigma_j)))$$
#
# that is associated with an Ising Hamiltonian
# $$H=\sum_{<ij>} [-\sigma_i \sigma_j - 0.5 h(\sigma_i +\sigma_j)]$$

# %%
import numpy as np
from numpy import linalg as LA
from scipy.sparse.linalg import LinearOperator, eigs
from ncon import ncon
import matplotlib.pyplot as plt
beta= np.log(1.+np.sqrt(2.))/2.
h = 0.0
#H =- s s -h s
Boltz_weight=np.zeros([2,2])
for s_1 in [0,1]:
    for s_2 in [0,1]:
        sigma_1=2.*(s_1-0.5)
        sigma_2=2.*(s_2-0.5)
        Boltz_weight[s_1,s_2]=(np.exp(beta*sigma_1*sigma_2+
                                           beta*h*0.5*(sigma_1+sigma_2)))

# %% [markdown]
# ## Local Tensor
#  We now build the elementary four legs tensor $$T$$ we will use for the contraction using the Boltzman weight and the copy tensor as in the left part of the figure, we will define a function that accepts two arguments $\beta, h$
# ![image.png](attachment:image.png)

# %%
def local_tensor_T(beta, h):
#H =- s s -h s
    Boltz_weight=np.zeros([2,2])
    for s_1 in [0,1]:
        for s_2 in [0,1]:
            sigma_1=2.*(s_1-0.5)
            sigma_2=2.*(s_2-0.5)
            Boltz_weight[s_1,s_2]=(np.exp(beta*sigma_1*sigma_2+
                                               beta*h*0.5*(sigma_1+sigma_2)))    

    
    
    copy_3= np.zeros([2,2,2])
    #copy_4= np.zeros([2,2,2,2])
    
    for s in [0,1]:
        copy_3[s,s,s]=1.
        #copy_4[s,s,s,s]=1.
    
    list_tensors =[copy_3,
                   Boltz_weight,
                   copy_3,
                   Boltz_weight,
                   copy_3,
                   Boltz_weight,
                   copy_3,
                   Boltz_weight]    
    list_indices =[[-1,1,8],[1,2],[2,-2,3],[3,4],
                    [4,-3,5],[5,6],[6,-4,7],[7,8]]
    tensor_z_two_dim = ncon(list_tensors,list_indices)
    return tensor_z_two_dim

# %% [markdown]
# ## Multiplying the infinite transfer matrix
#
#
#
# Now  we need to code the two functions that perform the contraction of the partition function and the numerator for the magnetization,
# ![image-2.png](attachment:image-2.png)
#
# *** In this plot
#
# the MPS matrices are found as the fixed point of the tranfer matrix operator defined in terms of the $$T$$ tensors above
#
# ![](../pictures/eig_equation.png)
#
#
# Notice that the local red tensor is just a $$\sigma_z$$ operator, that allows us to compute the local magnetization since
#
# $$<\sigma_R> =\frac{\sum_{\{\sigma\}}\sigma_R \exp[-{\beta H}]}{Z}$$
#
#
# The problem is thus
# ***GIVEN T*** find ***A*** where ***A*** is the three leg tensor.
#
# ## In the canonical form
# When the MPS is in the canonical form the above contraction becomes
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Exercise 1
# Fill the missing lines in the code to provide the correct tensor contractions for both numerator and denominator of the calculation of the magnetization (the tensor networks in the previous drawing).
#
# The ordering of the legs for the tensors is given in the figure and all $C$ and all $T$ are the same.
#
# ![](../pictures/bc_ingredients_ord.png)

# %%
def compute_norm_and_mag(A,sA,Op):
    numerator = ncon([np.diag(sA**2),A,np.diag(sA**2),A.conj(),Op],
                   [[4,1],[1,5,2],[2,3],[4,6,3],[5,6]]
                    )
    norm = ncon([np.diag(sA**2),A,np.diag(sA**2),A.conj(),np.eye(2)],
                              [[4,1],[1,5,2],[2,3],[4,6,3],[5,6]])
    
    return(numerator, norm)

# %% [markdown]
# ## One step
#
# Now the core of the boundary contraction method is to find the fixed point of the transformation
#
# ![](../pictures/local_tn.png)
# $$\chi \le \chi_{max}$$
#
#
#
#
# In order to do that we first need to absorb the $$T$$ tensor into the $$A$$ tensor
#
#
#
#
# ## Exercice two complete the code
#
# The function should abosrb one $$T$$ tensor into each $$A$$ tensor.

# %%
def contract_T_MPS(MPS,MPO):
     d = MPS.shape[1]
     chi = MPS.shape[0]
     list_tensor=[MPS,MPO]
     list_indices =[[-1,1,-4],[-3,-2,1,-5]]
     AO =ncon(list_tensor,list_indices).reshape(d*chi,d,d*chi)
     return AO

# %% [markdown]
#  ## Going to the canonical representation
#
# Now in order to truncate the larger bond of the $$A$$ tensor in a meaningful way, we need to go the canonical representation.
# This requires
#  1. finding the leading vectors (right and left)  of the MPS transfer matrix,
#  2. setting them to the identity using a gauge transformation $X X^{-1}$,
#  $Y Y^{-1}$
#  3. Performing a singular value  the resulting link matrix $Xs_AY$ and reabsorbing the unitaries on both sides
#
#  ***NOTICE*** that in step 3. we will directly truncate to a maximal bond dimension $\chi_{max}$ by keeping only the largest $\chi_max$ singular values
#  At the end this was all the reason to go to the canoncial gauge.
#
#  The first step is performed by the following function
#
#  ## Exercice 3 complete the TN contraction

# %%
def eig_TM_A(A):
    chi = A.shape[0]
    v0 =np.random.rand(chi*chi)
    def mult_tm_left(v0):
        chi = A.shape[0]
        v0 =ncon([A,A.conj(),v0.reshape(chi,chi)],
                 [[1,2,-1],[3,2,-2],[1,3]])
        
        return v0.reshape(chi*chi)
    def mult_tm_right(v0):
         chi = A.shape[0]
         v0 =ncon([A,A.conj(),v0.reshape(chi,chi)],
                  [[-1,2,1],[-2,2,3],[1,3]])
         return v0.reshape(chi*chi)
     
         
    e_L, L = eigs(LinearOperator((chi**2, chi**2), 
                                 matvec=mult_tm_left),
                        k=1, which='LM', v0=v0, tol=1e-10)
    e_R, R = eigs(LinearOperator((chi**2, chi**2), 
                                 matvec=mult_tm_right),
                        k=1, which='LM', v0=v0, tol=1e-10)
    R = R.reshape(chi,chi)
    L = L.reshape(chi,chi)
    #print(np.sum(L-L.T.conj()))
    #print(np.sum(R-R.T.conj()))
    L = 0.5*(L+L.T.conj())/(np.trace(L)/np.abs(np.trace(L)))
    R = 0.5*(R+R.T.conj())/(np.trace(R)/np.abs(np.trace(R)))
    A =A/np.sqrt(e_L)
    return(L,R,A)

# %% [markdown]
#  Step 2 & 3 are performed by the following function

# %%
def orthogonalize_A(L,R,A,sA,dtol=1.e-12,max_chi=16):
    # diagonalize left environment matrix

    dtemp, utemp = LA.eigh(L)
    chitemp = sum(dtemp > dtol)
    chitemp =min(chitemp,max_chi) 
    DL = dtemp[range(-1, -chitemp - 1, -1)]
    UL = utemp[:, range(-1, -chitemp - 1, -1)]

    # diagonalize right environment matrix
    dtemp, utemp = LA.eigh(R)
    chitemp = sum(dtemp > dtol)
    chitemp =min(chitemp,max_chi) 
    DR = dtemp[range(-1, -chitemp - 1, -1)]
    UR = utemp[:, range(-1, -chitemp - 1, -1)]
    weighted_mat = (np.diag(np.sqrt(DL)) @ UL.T @ np.diag(sA)
                    @ UR @ np.diag(np.sqrt(DR)))
    
    UA, stemp, VhA = LA.svd(weighted_mat, full_matrices=False)
    sA = stemp / LA.norm(stemp)
    x = np.conj(UL) @ np.diag(1 / np.sqrt(DL)) @ UA
    y = np.conj(UR) @ np.diag(1 / np.sqrt(DR)) @ VhA.T
    A = ncon([y, A], [[1, -1], [1, -2, -3]])
    A = ncon([A, x], [[-1, -2, 2], [2, -3]])
    return A, sA

# %% [markdown]
# In order to compare with the exact result we need to compute also the exact magnetization for $\beta\ge \beta_c$ given by
# $$M = \left[ 1 - \sinh^{-4}(2 \beta) \right]^{1/8}$$

# %%
def exact_mag(beta):
    return (1 - np.sinh(2*beta)**(-4))**(1/8)

# %% [markdown]
# ## Now we put it all togethe
#
#
# Now we can put all together, since the boundary contraction is an iterative method one should take care about the convergence, by e.g. tracking the magnetization and repeating the algorithm untill it stop changing (up to a desired accuracy). For simplicity here we will fix the number of iteration to 100 and run the program for different $\beta$.

# %%
max_chi=4
dtol = 1.e-10
numiter=200
list_mag=[]
b_start=0.42
b_fin =0.48
b_steps =50
x= np.linspace(b_start,b_fin,b_steps)
Op=np.array([[1,0],[0,-1]])
for beta in x:
    T= local_tensor_T(beta, h)
    A = T[:,:,0,:]
  
    sA = np.ones(A.shape[0])
    
    for k in range(numiter+1):
        #absorb the weight
        A = ncon([np.diag(np.sqrt(sA)),A,np.diag(np.sqrt(sA))],[[-1,2],
                                        [2,-2,1],[1,-3]])
        AT = contract_T_MPS(A,T)
        chi_A =AT.shape[0]
        #print(chi_A)
        L,R,AT =eig_TM_A(AT)
        #print(ncon([L,AT,R,AT.conj()],[[1,5],[1,4,2],[2,3],[5,4,3]]))
        A ,sA = orthogonalize_A(L,R,AT,np.ones(chi_A),dtol,max_chi)
        mag = ncon([np.diag(sA**2),A,np.diag(sA**2),A.conj(),Op],
                   [[4,1],[1,5,2],[2,3],[4,6,3],[5,6]]
                    )
        norm = ncon([np.diag(sA**2),A,np.diag(sA**2),A.conj(),np.eye(2)],
                              [[4,1],[1,5,2],[2,3],[4,6,3],[5,6]])
             
        print('Beta :%g, ite %d: Mag :%g, Norm: %g, Chi :%d'%(beta, k, 
                                                              np.real_if_close(mag),
                                                              np.real_if_close(norm), chi_A))
    
    list_mag.append(mag)
# Out:
# Beta :0.42, ite 0: Mag :0.812943, Norm: 1.00486, Chi :4
# Beta :0.42, ite 1: Mag :0.740828, Norm: 1, Chi :8
# Beta :0.42, ite 2: Mag :0.684945, Norm: 1, Chi :8
# Beta :0.42, ite 3: Mag :0.635433, Norm: 1, Chi :8
# Beta :0.42, ite 4: Mag :0.589695, Norm: 1, Chi :8
# Beta :0.42, ite 5: Mag :0.546495, Norm: 1, Chi :8
# Beta :0.42, ite 6: Mag :0.505255, Norm: 1, Chi :8
# Beta :0.42, ite 7: Mag :0.465745, Norm: 1, Chi :8
# Beta :0.42, ite 8: Mag :0.427927, Norm: 1, Chi :8
# Beta :0.42, ite 9: Mag :0.391864, Norm: 1, Chi :8
# Beta :0.42, ite 10: Mag :0.357657, Norm: 1, Chi :8
# Beta :0.42, ite 11: Mag :0.325412, Norm: 1, Chi :8
# Beta :0.42, ite 12: Mag :0.295214, Norm: 1, Chi :8
# Beta :0.42, ite 13: Mag :0.267112, Norm: 1, Chi :8
# Beta :0.42, ite 14: Mag :0.241117, Norm: 1, Chi :8
# Beta :0.42, ite 15: Mag :0.217205, Norm: 1, Chi :8
# Beta :0.42, ite 16: Mag :0.195315, Norm: 1, Chi :8
# Beta :0.42, ite 17: Mag :0.175364, Norm: 1, Chi :8
# Beta :0.42, ite 18: Mag :0.157249, Norm: 1, Chi :8
# Beta :0.42, ite 19: Mag :0.140853, Norm: 1, Chi :8
# Beta :0.42, ite 20: Mag :0.126052, Norm: 1, Chi :8
# Beta :0.42, ite 21: Mag :0.112723, Norm: 1, Chi :8
# Beta :0.42, ite 22: Mag :0.100742, Norm: 1, Chi :8
# Beta :0.42, ite 23: Mag :0.0899886, Norm: 1, Chi :8
# Beta :0.42, ite 24: Mag :0.0803503, Norm: 1, Chi :8
# Beta :0.42, ite 25: Mag :0.0717204, Norm: 1, Chi :8
# Beta :0.42, ite 26: Mag :0.064, Norm: 1, Chi :8
# Beta :0.42, ite 27: Mag :0.0570982, Norm: 1, Chi :8
# Beta :0.42, ite 28: Mag :0.0509317, Norm: 1, Chi :8
# Beta :0.42, ite 29: Mag :0.0454248, Norm: 1, Chi :8
# Beta :0.42, ite 30: Mag :0.0405086, Norm: 1, Chi :8
# Beta :0.42, ite 31: Mag :0.0361211, Norm: 1, Chi :8
# Beta :0.42, ite 32: Mag :0.0322065, Norm: 1, Chi :8
# Beta :0.42, ite 33: Mag :0.0287145, Norm: 1, Chi :8
# Beta :0.42, ite 34: Mag :0.0255998, Norm: 1, Chi :8
# Beta :0.42, ite 35: Mag :0.0228222, Norm: 1, Chi :8
# Beta :0.42, ite 36: Mag :0.0203453, Norm: 1, Chi :8
# Beta :0.42, ite 37: Mag :0.0181368, Norm: 1, Chi :8
# Beta :0.42, ite 38: Mag :0.0161677, Norm: 1, Chi :8
# Beta :0.42, ite 39: Mag :0.0144122, Norm: 1, Chi :8
# Beta :0.42, ite 40: Mag :0.0128471, Norm: 1, Chi :8
# Beta :0.42, ite 41: Mag :0.0114519, Norm: 1, Chi :8
# Beta :0.42, ite 42: Mag :0.0102081, Norm: 1, Chi :8
# Beta :0.42, ite 43: Mag :0.00909939, Norm: 1, Chi :8
# Beta :0.42, ite 44: Mag :0.00811102, Norm: 1, Chi :8
# Beta :0.42, ite 45: Mag :0.00722999, Norm: 1, Chi :8
# Beta :0.42, ite 46: Mag :0.00644463, Norm: 1, Chi :8
# Beta :0.42, ite 47: Mag :0.00574457, Norm: 1, Chi :8
# Beta :0.42, ite 48: Mag :0.00512055, Norm: 1, Chi :8
# Beta :0.42, ite 49: Mag :0.0045643, Norm: 1, Chi :8
# Beta :0.42, ite 50: Mag :0.00406847, Norm: 1, Chi :8
# Beta :0.42, ite 51: Mag :0.00362651, Norm: 1, Chi :8
# Beta :0.42, ite 52: Mag :0.00323255, Norm: 1, Chi :8
# Beta :0.42, ite 53: Mag :0.00288139, Norm: 1, Chi :8
# Beta :0.42, ite 54: Mag :0.00256837, Norm: 1, Chi :8
# Beta :0.42, ite 55: Mag :0.00228936, Norm: 1, Chi :8
# Beta :0.42, ite 56: Mag :0.00204065, Norm: 1, Chi :8
# Beta :0.42, ite 57: Mag :0.00181897, Norm: 1, Chi :8
# Beta :0.42, ite 58: Mag :0.00162137, Norm: 1, Chi :8
# Beta :0.42, ite 59: Mag :0.00144523, Norm: 1, Chi :8
# Beta :0.42, ite 60: Mag :0.00128823, Norm: 1, Chi :8
# Beta :0.42, ite 61: Mag :0.00114828, Norm: 1, Chi :8
# Beta :0.42, ite 62: Mag :0.00102354, Norm: 1, Chi :8
# Beta :0.42, ite 63: Mag :0.000912343, Norm: 1, Chi :8
# Beta :0.42, ite 64: Mag :0.000813231, Norm: 1, Chi :8
# Beta :0.42, ite 65: Mag :0.000724885, Norm: 1, Chi :8
# Beta :0.42, ite 66: Mag :0.000646137, Norm: 1, Chi :8
# Beta :0.42, ite 67: Mag :0.000575943, Norm: 1, Chi :8
# Beta :0.42, ite 68: Mag :0.000513375, Norm: 1, Chi :8
# Beta :0.42, ite 69: Mag :0.000457605, Norm: 1, Chi :8
# Beta :0.42, ite 70: Mag :0.000407893, Norm: 1, Chi :8
# Beta :0.42, ite 71: Mag :0.000363581, Norm: 1, Chi :8
# Beta :0.42, ite 72: Mag :0.000324083, Norm: 1, Chi :8
# Beta :0.42, ite 73: Mag :0.000288876, Norm: 1, Chi :8
# Beta :0.42, ite 74: Mag :0.000257494, Norm: 1, Chi :8
# Beta :0.42, ite 75: Mag :0.000229521, Norm: 1, Chi :8
# Beta :0.42, ite 76: Mag :0.000204587, Norm: 1, Chi :8
# Beta :0.42, ite 77: Mag :0.000182361, Norm: 1, Chi :8
# Beta :0.42, ite 78: Mag :0.00016255, Norm: 1, Chi :8
# Beta :0.42, ite 79: Mag :0.000144892, Norm: 1, Chi :8
# Beta :0.42, ite 80: Mag :0.000129151, Norm: 1, Chi :8
# Beta :0.42, ite 81: Mag :0.000115121, Norm: 1, Chi :8
# Beta :0.42, ite 82: Mag :0.000102615, Norm: 1, Chi :8
# Beta :0.42, ite 83: Mag :9.14671e-05, Norm: 1, Chi :8
# Beta :0.42, ite 84: Mag :8.15305e-05, Norm: 1, Chi :8
# Beta :0.42, ite 85: Mag :7.26734e-05, Norm: 1, Chi :8
# Beta :0.42, ite 86: Mag :6.47785e-05, Norm: 1, Chi :8
# Beta :0.42, ite 87: Mag :5.77412e-05, Norm: 1, Chi :8
# Beta :0.42, ite 88: Mag :5.14685e-05, Norm: 1, Chi :8
# Beta :0.42, ite 89: Mag :4.58772e-05, Norm: 1, Chi :8
# Beta :0.42, ite 90: Mag :4.08933e-05, Norm: 1, Chi :8
# Beta :0.42, ite 91: Mag :3.64508e-05, Norm: 1, Chi :8
# Beta :0.42, ite 92: Mag :3.2491e-05, Norm: 1, Chi :8
# Beta :0.42, ite 93: Mag :2.89613e-05, Norm: 1, Chi :8
# Beta :0.42, ite 94: Mag :2.58151e-05, Norm: 1, Chi :8
# Beta :0.42, ite 95: Mag :2.30106e-05, Norm: 1, Chi :8
# Beta :0.42, ite 96: Mag :2.05108e-05, Norm: 1, Chi :8
# Beta :0.42, ite 97: Mag :1.82826e-05, Norm: 1, Chi :8
# Beta :0.42, ite 98: Mag :1.62965e-05, Norm: 1, Chi :8
# Beta :0.42, ite 99: Mag :1.45261e-05, Norm: 1, Chi :8
# Beta :0.42, ite 100: Mag :1.29481e-05, Norm: 1, Chi :8
# Beta :0.42, ite 101: Mag :1.15414e-05, Norm: 1, Chi :8
# Beta :0.42, ite 102: Mag :1.02876e-05, Norm: 1, Chi :8
# Beta :0.42, ite 103: Mag :9.17003e-06, Norm: 1, Chi :8
# Beta :0.42, ite 104: Mag :8.17384e-06, Norm: 1, Chi :8
# Beta :0.42, ite 105: Mag :7.28587e-06, Norm: 1, Chi :8
# Beta :0.42, ite 106: Mag :6.49436e-06, Norm: 1, Chi :8
# Beta :0.42, ite 107: Mag :5.78885e-06, Norm: 1, Chi :8
# Beta :0.42, ite 108: Mag :5.15997e-06, Norm: 1, Chi :8
# Beta :0.42, ite 109: Mag :4.59941e-06, Norm: 1, Chi :8
# Beta :0.42, ite 110: Mag :4.09975e-06, Norm: 1, Chi :8
# Beta :0.42, ite 111: Mag :3.65438e-06, Norm: 1, Chi :8
# Beta :0.42, ite 112: Mag :3.25738e-06, Norm: 1, Chi :8
# Beta :0.42, ite 113: Mag :2.90351e-06, Norm: 1, Chi :8
# Beta :0.42, ite 114: Mag :2.58809e-06, Norm: 1, Chi :8
# Beta :0.42, ite 115: Mag :2.30693e-06, Norm: 1, Chi :8
# Beta :0.42, ite 116: Mag :2.05632e-06, Norm: 1, Chi :8
# Beta :0.42, ite 117: Mag :1.83293e-06, Norm: 1, Chi :8
# Beta :0.42, ite 118: Mag :1.63381e-06, Norm: 1, Chi :8
# Beta :0.42, ite 119: Mag :1.45632e-06, Norm: 1, Chi :8
# Beta :0.42, ite 120: Mag :1.29811e-06, Norm: 1, Chi :8
# Beta :0.42, ite 121: Mag :1.15709e-06, Norm: 1, Chi :8
# Beta :0.42, ite 122: Mag :1.03139e-06, Norm: 1, Chi :8
# Beta :0.42, ite 123: Mag :9.19342e-07, Norm: 1, Chi :8
# Beta :0.42, ite 124: Mag :8.19468e-07, Norm: 1, Chi :8
# Beta :0.42, ite 125: Mag :7.30445e-07, Norm: 1, Chi :8
# Beta :0.42, ite 126: Mag :6.51093e-07, Norm: 1, Chi :8
# Beta :0.42, ite 127: Mag :5.80361e-07, Norm: 1, Chi :8
# Beta :0.42, ite 128: Mag :5.17313e-07, Norm: 1, Chi :8
# Beta :0.42, ite 129: Mag :4.61114e-07, Norm: 1, Chi :8
# Beta :0.42, ite 130: Mag :4.11021e-07, Norm: 1, Chi :8
# Beta :0.42, ite 131: Mag :3.6637e-07, Norm: 1, Chi :8
# Beta :0.42, ite 132: Mag :3.26569e-07, Norm: 1, Chi :8
# Beta :0.42, ite 133: Mag :2.91092e-07, Norm: 1, Chi :8
# Beta :0.42, ite 134: Mag :2.59469e-07, Norm: 1, Chi :8
# Beta :0.42, ite 135: Mag :2.31281e-07, Norm: 1, Chi :8
# Beta :0.42, ite 136: Mag :2.06156e-07, Norm: 1, Chi :8
# Beta :0.42, ite 137: Mag :1.8376e-07, Norm: 1, Chi :8
# Beta :0.42, ite 138: Mag :1.63797e-07, Norm: 1, Chi :8
# Beta :0.42, ite 139: Mag :1.46003e-07, Norm: 1, Chi :8
# Beta :0.42, ite 140: Mag :1.30142e-07, Norm: 1, Chi :8
# Beta :0.42, ite 141: Mag :1.16004e-07, Norm: 1, Chi :8
# Beta :0.42, ite 142: Mag :1.03402e-07, Norm: 1, Chi :8
# Beta :0.42, ite 143: Mag :9.21687e-08, Norm: 1, Chi :8
# Beta :0.42, ite 144: Mag :8.21559e-08, Norm: 1, Chi :8
# Beta :0.42, ite 145: Mag :7.32308e-08, Norm: 1, Chi :8
# Beta :0.42, ite 146: Mag :6.52753e-08, Norm: 1, Chi :8
# Beta :0.42, ite 147: Mag :5.81841e-08, Norm: 1, Chi :8
# Beta :0.42, ite 148: Mag :5.18631e-08, Norm: 1, Chi :8
# Beta :0.42, ite 149: Mag :4.6229e-08, Norm: 1, Chi :8
# Beta :0.42, ite 150: Mag :4.12068e-08, Norm: 1, Chi :8
# Beta :0.42, ite 151: Mag :3.67303e-08, Norm: 1, Chi :8
# Beta :0.42, ite 152: Mag :3.274e-08, Norm: 1, Chi :8
# Beta :0.42, ite 153: Mag :2.91834e-08, Norm: 1, Chi :8
# Beta :0.42, ite 154: Mag :2.6013e-08, Norm: 1, Chi :8
# Beta :0.42, ite 155: Mag :2.31872e-08, Norm: 1, Chi :8
# Beta :0.42, ite 156: Mag :2.06682e-08, Norm: 1, Chi :8
# Beta :0.42, ite 157: Mag :1.84229e-08, Norm: 1, Chi :8
# Beta :0.42, ite 158: Mag :1.64214e-08, Norm: 1, Chi :8
# Beta :0.42, ite 159: Mag :1.46375e-08, Norm: 1, Chi :8
# Beta :0.42, ite 160: Mag :1.30473e-08, Norm: 1, Chi :8
# Beta :0.42, ite 161: Mag :1.163e-08, Norm: 1, Chi :8
# Beta :0.42, ite 162: Mag :1.03666e-08, Norm: 1, Chi :8
# Beta :0.42, ite 163: Mag :9.24048e-09, Norm: 1, Chi :8
# Beta :0.42, ite 164: Mag :8.23661e-09, Norm: 1, Chi :8
# Beta :0.42, ite 165: Mag :7.34182e-09, Norm: 1, Chi :8
# Beta :0.42, ite 166: Mag :6.5442e-09, Norm: 1, Chi :8
# Beta :0.42, ite 167: Mag :5.83326e-09, Norm: 1, Chi :8
# Beta :0.42, ite 168: Mag :5.19948e-09, Norm: 1, Chi :8
# Beta :0.42, ite 169: Mag :4.63465e-09, Norm: 1, Chi :8
# Beta :0.42, ite 170: Mag :4.13116e-09, Norm: 1, Chi :8
# Beta :0.42, ite 171: Mag :3.68243e-09, Norm: 1, Chi :8
# Beta :0.42, ite 172: Mag :3.28239e-09, Norm: 1, Chi :8
# Beta :0.42, ite 173: Mag :2.9259e-09, Norm: 1, Chi :8
# Beta :0.42, ite 174: Mag :2.60802e-09, Norm: 1, Chi :8
# Beta :0.42, ite 175: Mag :2.32469e-09, Norm: 1, Chi :8
# Beta :0.42, ite 176: Mag :2.07209e-09, Norm: 1, Chi :8
# Beta :0.42, ite 177: Mag :1.84698e-09, Norm: 1, Chi :8
# Beta :0.42, ite 178: Mag :1.64627e-09, Norm: 1, Chi :8
# Beta :0.42, ite 179: Mag :1.46745e-09, Norm: 1, Chi :8
# Beta :0.42, ite 180: Mag :1.30804e-09, Norm: 1, Chi :8
# Beta :0.42, ite 181: Mag :1.16599e-09, Norm: 1, Chi :8
# Beta :0.42, ite 182: Mag :1.03932e-09, Norm: 1, Chi :8
# Beta :0.42, ite 183: Mag :9.26485e-10, Norm: 1, Chi :8
# Beta :0.42, ite 184: Mag :8.25843e-10, Norm: 1, Chi :8
# Beta :0.42, ite 185: Mag :7.3622e-10, Norm: 1, Chi :8
# Beta :0.42, ite 186: Mag :6.56208e-10, Norm: 1, Chi :8
# Beta :0.42, ite 187: Mag :5.84921e-10, Norm: 1, Chi :8
# Beta :0.42, ite 188: Mag :5.21314e-10, Norm: 1, Chi :8
# Beta :0.42, ite 189: Mag :4.64676e-10, Norm: 1, Chi :8
# Beta :0.42, ite 190: Mag :4.14104e-10, Norm: 1, Chi :8
# Beta :0.42, ite 191: Mag :3.69142e-10, Norm: 1, Chi :8
# Beta :0.42, ite 192: Mag :3.29039e-10, Norm: 1, Chi :8
# Beta :0.42, ite 193: Mag :2.93343e-10, Norm: 1, Chi :8
# Beta :0.42, ite 194: Mag :2.61483e-10, Norm: 1, Chi :8
# Beta :0.42, ite 195: Mag :2.33155e-10, Norm: 1, Chi :8
# Beta :0.42, ite 196: Mag :2.078e-10, Norm: 1, Chi :8
# Beta :0.42, ite 197: Mag :1.85215e-10, Norm: 1, Chi :8
# Beta :0.42, ite 198: Mag :1.65006e-10, Norm: 1, Chi :8
# Beta :0.42, ite 199: Mag :1.47105e-10, Norm: 1, Chi :8
# Beta :0.42, ite 200: Mag :1.31113e-10, Norm: 1, Chi :8
# Beta :0.421224, ite 0: Mag :0.815629, Norm: 1.00476, Chi :4
# Beta :0.421224, ite 1: Mag :0.745457, Norm: 1, Chi :8
# Beta :0.421224, ite 2: Mag :0.69156, Norm: 1, Chi :8
# Beta :0.421224, ite 3: Mag :0.644125, Norm: 1, Chi :8
# Beta :0.421224, ite 4: Mag :0.600513, Norm: 1, Chi :8
# Beta :0.421224, ite 5: Mag :0.559433, Norm: 1, Chi :8
# Beta :0.421224, ite 6: Mag :0.520243, Norm: 1, Chi :8
# Beta :0.421224, ite 7: Mag :0.482647, Norm: 1, Chi :8
# Beta :0.421224, ite 8: Mag :0.446546, Norm: 1, Chi :8
# Beta :0.421224, ite 9: Mag :0.411949, Norm: 1, Chi :8
# Beta :0.421224, ite 10: Mag :0.378923, Norm: 1, Chi :8
# Beta :0.421224, ite 11: Mag :0.347553, Norm: 1, Chi :8
# Beta :0.421224, ite 12: Mag :0.317921, Norm: 1, Chi :8
# Beta :0.421224, ite 13: Mag :0.290089, Norm: 1, Chi :8
# Beta :0.421224, ite 14: Mag :0.264092, Norm: 1, Chi :8
# Beta :0.421224, ite 15: Mag :0.239934, Norm: 1, Chi :8
# Beta :0.421224, ite 16: Mag :0.217595, Norm: 1, Chi :8
# Beta :0.421224, ite 17: Mag :0.197025, Norm: 1, Chi :8
# Beta :0.421224, ite 18: Mag :0.178158, Norm: 1, Chi :8
# Beta :0.421224, ite 19: Mag :0.160911, Norm: 1, Chi :8
# Beta :0.421224, ite 20: Mag :0.14519, Norm: 1, Chi :8
# Beta :0.421224, ite 21: Mag :0.130896, Norm: 1, Chi :8
# Beta :0.421224, ite 22: Mag :0.117926, Norm: 1, Chi :8
# Beta :0.421224, ite 23: Mag :0.10618, Norm: 1, Chi :8
# Beta :0.421224, ite 24: Mag :0.0955571, Norm: 1, Chi :8
# Beta :0.421224, ite 25: Mag :0.0859626, Norm: 1, Chi :8
# Beta :0.421224, ite 26: Mag :0.0773058, Norm: 1, Chi :8
# Beta :0.421224, ite 27: Mag :0.0695018, Norm: 1, Chi :8
# Beta :0.421224, ite 28: Mag :0.0624716, Norm: 1, Chi :8
# Beta :0.421224, ite 29: Mag :0.0561422, Norm: 1, Chi :8
# Beta :0.421224, ite 30: Mag :0.0504465, Norm: 1, Chi :8
# Beta :0.421224, ite 31: Mag :0.0453231, Norm: 1, Chi :8
# Beta :0.421224, ite 32: Mag :0.0407159, Norm: 1, Chi :8
# Beta :0.421224, ite 33: Mag :0.0365741, Norm: 1, Chi :8
# Beta :0.421224, ite 34: Mag :0.0328515, Norm: 1, Chi :8
# Beta :0.421224, ite 35: Mag :0.0295062, Norm: 1, Chi :8
# Beta :0.421224, ite 36: Mag :0.0265003, Norm: 1, Chi :8
# Beta :0.421224, ite 37: Mag :0.0237999, Norm: 1, Chi :8
# Beta :0.421224, ite 38: Mag :0.021374, Norm: 1, Chi :8
# Beta :0.421224, ite 39: Mag :0.0191949, Norm: 1, Chi :8
# Beta :0.421224, ite 40: Mag :0.0172377, Norm: 1, Chi :8
# Beta :0.421224, ite 41: Mag :0.0154798, Norm: 1, Chi :8
# Beta :0.421224, ite 42: Mag :0.013901, Norm: 1, Chi :8
# Beta :0.421224, ite 43: Mag :0.0124831, Norm: 1, Chi :8
# Beta :0.421224, ite 44: Mag :0.0112097, Norm: 1, Chi :8
# Beta :0.421224, ite 45: Mag :0.0100662, Norm: 1, Chi :8
# Beta :0.421224, ite 46: Mag :0.00903926, Norm: 1, Chi :8
# Beta :0.421224, ite 47: Mag :0.00811706, Norm: 1, Chi :8
# Beta :0.421224, ite 48: Mag :0.00728892, Norm: 1, Chi :8
# Beta :0.421224, ite 49: Mag :0.00654525, Norm: 1, Chi :8
# Beta :0.421224, ite 50: Mag :0.00587744, Norm: 1, Chi :8
# Beta :0.421224, ite 51: Mag :0.00527776, Norm: 1, Chi :8
# Beta :0.421224, ite 52: Mag :0.00473926, Norm: 1, Chi :8
# Beta :0.421224, ite 53: Mag :0.0042557, Norm: 1, Chi :8
# Beta :0.421224, ite 54: Mag :0.00382147, Norm: 1, Chi :8
# Beta :0.421224, ite 55: Mag :0.00343155, Norm: 1, Chi :8
# Beta :0.421224, ite 56: Mag :0.00308141, Norm: 1, Chi :8
# Beta :0.421224, ite 57: Mag :0.002767, Norm: 1, Chi :8
# Beta :0.421224, ite 58: Mag :0.00248466, Norm: 1, Chi :8
# Beta :0.421224, ite 59: Mag :0.00223114, Norm: 1, Chi :8
# Beta :0.421224, ite 60: Mag :0.00200348, Norm: 1, Chi :8
# Beta :0.421224, ite 61: Mag :0.00179905, Norm: 1, Chi :8
# Beta :0.421224, ite 62: Mag :0.00161548, Norm: 1, Chi :8
# Beta :0.421224, ite 63: Mag :0.00145064, Norm: 1, Chi :8
# Beta :0.421224, ite 64: Mag :0.00130262, Norm: 1, Chi :8
# Beta :0.421224, ite 65: Mag :0.00116971, Norm: 1, Chi :8
# Beta :0.421224, ite 66: Mag :0.00105035, Norm: 1, Chi :8
# Beta :0.421224, ite 67: Mag :0.000943178, Norm: 1, Chi :8
# Beta :0.421224, ite 68: Mag :0.000846939, Norm: 1, Chi :8
# Beta :0.421224, ite 69: Mag :0.000760519, Norm: 1, Chi :8
# Beta :0.421224, ite 70: Mag :0.000682918, Norm: 1, Chi :8
# Beta :0.421224, ite 71: Mag :0.000613235, Norm: 1, Chi :8
# Beta :0.421224, ite 72: Mag :0.000550662, Norm: 1, Chi :8
# Beta :0.422449, ite 18: Mag :0.201233, Norm: 1, Chi :8
# Beta :0.422449, ite 19: Mag :0.183282, Norm: 1, Chi :8
# Beta :0.422449, ite 20: Mag :0.166756, Norm: 1, Chi :8
# Beta :0.422449, ite 21: Mag :0.151581, Norm: 1, Chi :8
# Beta :0.422449, ite 22: Mag :0.13768, Norm: 1, Chi :8
# Beta :0.422449, ite 23: Mag :0.124971, Norm: 1, Chi :8
# Beta :0.422449, ite 24: Mag :0.113371, Norm: 1, Chi :8
# Beta :0.422449, ite 25: Mag :0.102799, Norm: 1, Chi :8
# Beta :0.422449, ite 26: Mag :0.0931762, Norm: 1, Chi :8
# Beta :0.422449, ite 27: Mag :0.0844257, Norm: 1, Chi :8
# Beta :0.422449, ite 28: Mag :0.0764756, Norm: 1, Chi :8
# Beta :0.422449, ite 29: Mag :0.069258, Norm: 1, Chi :8
# Beta :0.422449, ite 30: Mag :0.0627094, Norm: 1, Chi :8
# Beta :0.422449, ite 31: Mag :0.0567709, Norm: 1, Chi :8
# Beta :0.422449, ite 32: Mag :0.0513879, Norm: 1, Chi :8
# Beta :0.422449, ite 33: Mag :0.0465103, Norm: 1, Chi :8
# Beta :0.422449, ite 34: Mag :0.0420917, Norm: 1, Chi :8
# Beta :0.422449, ite 35: Mag :0.0380901, Norm: 1, Chi :8
# Beta :0.422449, ite 36: Mag :0.0344667, Norm: 1, Chi :8
# Beta :0.422449, ite 37: Mag :0.0311865, Norm: 1, Chi :8
# Beta :0.422449, ite 38: Mag :0.0282172, Norm: 1, Chi :8
# Beta :0.422449, ite 39: Mag :0.0255297, Norm: 1, Chi :8
# Beta :0.422449, ite 40: Mag :0.0230976, Norm: 1, Chi :8
# Beta :0.422449, ite 41: Mag :0.0208967, Norm: 1, Chi :8
# Beta :0.422449, ite 42: Mag :0.0189051, Norm: 1, Chi :8
# Beta :0.422449, ite 43: Mag :0.017103, Norm: 1, Chi :8
# Beta :0.422449, ite 44: Mag :0.0154726, Norm: 1, Chi :8
# Beta :0.422449, ite 45: Mag :0.0139974, Norm: 1, Chi :8
# Beta :0.422449, ite 46: Mag :0.0126627, Norm: 1, Chi :8
# Beta :0.422449, ite 47: Mag :0.0114553, Norm: 1, Chi :8
# Beta :0.422449, ite 48: Mag :0.0103629, Norm: 1, Chi :8
# Beta :0.422449, ite 49: Mag :0.00937462, Norm: 1, Chi :8
# Beta :0.422449, ite 50: Mag :0.00848057, Norm: 1, Chi :8
# Beta :0.422449, ite 51: Mag :0.00767176, Norm: 1, Chi :8
# Beta :0.422449, ite 52: Mag :0.00694007, Norm: 1, Chi :8
# Beta :0.422449, ite 53: Mag :0.00627815, Norm: 1, Chi :8
# Beta :0.422449, ite 54: Mag :0.00567935, Norm: 1, Chi :8
# Beta :0.422449, ite 55: Mag :0.00513766, Norm: 1, Chi :8
# Beta :0.422449, ite 56: Mag :0.00464763, Norm: 1, Chi :8
# Beta :0.422449, ite 57: Mag :0.00420433, Norm: 1, Chi :8
# Beta :0.422449, ite 58: Mag :0.00380331, Norm: 1, Chi :8
# Beta :0.422449, ite 59: Mag :0.00344054, Norm: 1, Chi :8
# Beta :0.422449, ite 60: Mag :0.00311237, Norm: 1, Chi :8
# Beta :0.422449, ite 61: Mag :0.0028155, Norm: 1, Chi :8
# Beta :0.422449, ite 62: Mag :0.00254695, Norm: 1, Chi :8
# Beta :0.422449, ite 63: Mag :0.00230401, Norm: 1, Chi :8
# Beta :0.422449, ite 64: Mag :0.00208424, Norm: 1, Chi :8
# Beta :0.422449, ite 65: Mag :0.00188544, Norm: 1, Chi :8
# Beta :0.422449, ite 66: Mag :0.0017056, Norm: 1, Chi :8
# Beta :0.422449, ite 67: Mag :0.00154291, Norm: 1, Chi :8
# Beta :0.422449, ite 68: Mag :0.00139574, Norm: 1, Chi :8
# Beta :0.422449, ite 69: Mag :0.0012626, Norm: 1, Chi :8
# Beta :0.422449, ite 70: Mag :0.00114217, Norm: 1, Chi :8
# Beta :0.422449, ite 71: Mag :0.00103322, Norm: 1, Chi :8
# Beta :0.422449, ite 72: Mag :0.00093467, Norm: 1, Chi :8
# Beta :0.422449, ite 73: Mag :0.000845517, Norm: 1, Chi :8
# Beta :0.422449, ite 74: Mag :0.000764867, Norm: 1, Chi :8
# Beta :0.422449, ite 75: Mag :0.00069191, Norm: 1, Chi :8
# Beta :0.422449, ite 76: Mag :0.000625912, Norm: 1, Chi :8
# Beta :0.422449, ite 77: Mag :0.000566209, Norm: 1, Chi :8
# Beta :0.422449, ite 78: Mag :0.000512201, Norm: 1, Chi :8
# Beta :0.422449, ite 79: Mag :0.000463344, Norm: 1, Chi :8
# Beta :0.422449, ite 80: Mag :0.000419148, Norm: 1, Chi :8
# Beta :0.422449, ite 81: Mag :0.000379167, Norm: 1, Chi :8
# Beta :0.422449, ite 82: Mag :0.000343, Norm: 1, Chi :8
# Beta :0.422449, ite 83: Mag :0.000310283, Norm: 1, Chi :8
# Beta :0.422449, ite 84: Mag :0.000280687, Norm: 1, Chi :8
# Beta :0.422449, ite 85: Mag :0.000253913, Norm: 1, Chi :8
# Beta :0.422449, ite 86: Mag :0.000229694, Norm: 1, Chi :8
# Beta :0.422449, ite 87: Mag :0.000207784, Norm: 1, Chi :8
# Beta :0.422449, ite 88: Mag :0.000187965, Norm: 1, Chi :8
# Beta :0.422449, ite 89: Mag :0.000170036, Norm: 1, Chi :8
# Beta :0.422449, ite 90: Mag :0.000153817, Norm: 1, Chi :8
# Beta :0.422449, ite 91: Mag :0.000139145, Norm: 1, Chi :8
# Beta :0.422449, ite 92: Mag :0.000125872, Norm: 1, Chi :8
# Beta :0.422449, ite 93: Mag :0.000113866, Norm: 1, Chi :8
# Beta :0.422449, ite 94: Mag :0.000103005, Norm: 1, Chi :8
# Beta :0.422449, ite 95: Mag :9.31797e-05, Norm: 1, Chi :8
# Beta :0.422449, ite 96: Mag :8.42917e-05, Norm: 1, Chi :8
# Beta :0.422449, ite 97: Mag :7.62515e-05, Norm: 1, Chi :8
# Beta :0.422449, ite 98: Mag :6.89782e-05, Norm: 1, Chi :8
# Beta :0.422449, ite 99: Mag :6.23987e-05, Norm: 1, Chi :8
# Beta :0.422449, ite 100: Mag :5.64468e-05, Norm: 1, Chi :8
# Beta :0.422449, ite 101: Mag :5.10626e-05, Norm: 1, Chi :8
# Beta :0.422449, ite 102: Mag :4.61919e-05, Norm: 1, Chi :8
# Beta :0.422449, ite
-09, Norm: 1, Chi :8
# Beta :0.422449, ite 199: Mag :2.7641e-09, Norm: 1, Chi :8
# Beta :0.422449, ite 200: Mag :2.50043e-09, Norm: 1, Chi :8
# Beta :0.423673, ite 0: Mag :0.820892, Norm: 1.00456, Chi :4
# Beta :0.423673, ite 1: Mag :0.754484, Norm: 1, Chi :8
# Beta :0.423673, ite 2: Mag :0.704425, Norm: 1, Chi :8
# Beta :0.423673, ite 3: Mag :0.661006, Norm: 1, Chi :8
# Beta :0.423673, ite 4: Mag :0.621533, Norm: 1, Chi :8
# Beta :0.423673, ite 5: Mag :0.584636, Norm: 1, Chi :8
# Beta :0.423673, ite 6: Mag :0.549577, Norm: 1, Chi :8
# Beta :0.423673, ite 7: Mag :0.515955, Norm: 1, Chi :8
# Beta :0.423673, ite 8: Mag :0.483563, Norm: 1, Chi :8
# Beta :0.423673, ite 9: Mag :0.452317, Norm: 1, Chi :8
# Beta :0.423673, ite 10: Mag :0.4222, Norm: 1, Chi :8
# Beta :0.423673, ite 11: Mag :0.39324, Norm: 1, Chi :8
# Beta :0.423673, ite 12: Mag :0.365483, Norm: 1, Chi :8
# Beta :0.423673, ite 13: Mag :0.33898, Norm: 1, Chi :8
# Beta :0.423673, ite 14: Mag :0.313779, Norm: 1, Chi :8
# Beta :0.423673, ite 15: Mag :0.289916, Norm: 1, Chi :8
# Beta :0.423673, ite 16: Mag :0.267412, Norm: 1, Chi :8
# Beta :0.423673, ite 17: Mag :0.246273, Norm: 1, Chi :8
# Beta :0.423673, ite 18: Mag :0.226488, Norm: 1, Chi :8
# Beta :0.423673, ite 19: Mag :0.208033, Norm: 1, Chi :8
# Beta :0.423673, ite 20: Mag :0.19087, Norm: 1, Chi :8
# Beta :0.423673, ite 21: Mag :0.174954, Norm: 1, Chi :8
# Beta :0.423673, ite 22: Mag :0.160229, Norm: 1, Chi :8
# Beta :0.423673, ite 23: Mag :0.146635, Norm: 1, Chi :8
# Beta :0.423673, ite 24: Mag :0.13411, Norm: 1, Chi :8
# Beta :0.423673, ite 25: Mag :0.122587, Norm: 1, Chi :8
# Beta :0.423673, ite 26: Mag :0.112002, Norm: 1, Chi :8
# Beta :0.423673, ite 27: Mag :0.10229, Norm: 1, Chi :8
# Beta :0.423673, ite 28: Mag :0.0933881, Norm: 1, Chi :8
# Beta :0.423673, ite 29: Mag :0.0852366, Norm: 1, Chi :8
# Beta :0.423673, ite 30: Mag :0.0777775, Norm: 1, Chi :8
# Beta :0.423673, ite 31: Mag :0.0709566, Norm: 1, Chi :8
# Beta :0.423673, ite 32: Mag :0.0647225, Norm: 1, Chi :8
# Beta :0.423673, ite 33: Mag :0.0590276, Norm: 1, Chi :8
# Beta :0.423673, ite 34: Mag :0.0538271, Norm: 1, Chi :8
# Beta :0.423673, ite 35: Mag :0.0490797, Norm: 1, Chi :8
# Beta :0.423673, ite 36: Mag :0.0447471, Norm: 1, Chi :8
# Beta :0.423673, ite 37: Mag :0.040794, Norm: 1, Chi :8
# Beta :0.423673, ite 38: Mag :0.0371879, Norm: 1, Chi :8
# Beta :0.423673, ite 39: Mag :0.0338989, Norm: 1, Chi :8
# Beta :0.423673, ite 40: Mag :0.0308994, Norm: 1, Chi :8
# Beta :0.423673, ite 41: Mag :0.0281643, Norm: 1, Chi :8
